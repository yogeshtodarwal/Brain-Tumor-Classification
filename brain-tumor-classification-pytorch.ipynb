# %%
# torch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.transforms import transforms
import torch.optim as optim
# utils
import os
from glob import glob
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
# visualization
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix

# %%
# global variables
device = "cuda" if torch.cuda.is_available() else "cpu"
dataset_path = "/kaggle/input/brain-tumor-mri-dataset"
train_path = "/kaggle/input/brain-tumor-mri-dataset/Training"
test_path = "/kaggle/input/brain-tumor-mri-dataset/Testing"
image_size = (224,224)
num_classes = 5
train_paths = glob(f"{train_path}/*/*.jpg")
test_paths = glob(f"{test_path}/*/*.jpg")

# %%
# check device
device
# Out:
# 'cuda'

# %%
# data augmentation
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(10),
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# custom dataset class
class dataset(Dataset):
    def __init__(self,paths,transform=None):
        self.paths = paths
        self.transform = transform
        self.labels = [self.get_label(path) for path in self.paths]
        self.labels_to_index = {label:index for index,label in enumerate(list(set(self.labels)))}
    
    def __getitem__(self,index):
        img_path = self.paths[index]
        img = Image.open(img_path).convert('RGB') 
        label = self.labels[index]
        label_index = self.labels_to_index[label]
        
        if self.transform:
            img = self.transform(img)
        
        return img, label_index,label
    
    
    def __len__(self):
        return len(self.paths)
    
    
    def get_label(self, path):
        return os.path.basename(os.path.dirname(path))

# %%
train_dataset = dataset(train_paths, transform=train_transform)
test_dataset = dataset(test_paths, transform=test_transform)

# %%
val_dataset, test_dataset = train_test_split(test_dataset,test_size=0.5, random_state=ord("H"))

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# display sample images with classes
train_iter = iter(train_loader)
images, labels_indices, labels = next(train_iter)

def imshow(input_images, labels_indices,labels):
    label_dict = {"notumor":"No Tumor", "glioma":"Glioma", "meningioma":"Meningioma","pituitary":"Pituitary"}
    input_images=input_images.numpy().transpose((0,2, 3, 1))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input_images = std * input_images + mean
    input_images = np.clip(input_images, 0, 1)
    fig, axes = plt.subplots(8, 4, figsize=(8, 16))
    for i, ax in enumerate(axes.flat):
        ax.imshow(input_images[i])
        ax.axis('off')
        ax.set_title(label_dict[labels[i]], fontsize=12)
    plt.tight_layout()
    plt.show()


imshow(images, labels_indices,labels)

# %%
class MyModel(nn.Module):
    def __init__(self,num_classes):
        super(MyModel,self).__init__()
        
        self.conv1 = nn.Conv2d(3,32,kernel_size=4,stride=1,padding=0)
        self.bn1 = nn.BatchNorm2d(32)
        
        self.conv2 = nn.Conv2d(32,64,kernel_size=4,stride=1,padding=0)
        self.bn2 = nn.BatchNorm2d(64)
        
        self.conv3 = nn.Conv2d(64,128,kernel_size=4,stride=1,padding=0)
        self.bn3 = nn.BatchNorm2d(128)
        
        self.conv4 = nn.Conv2d(128,128,kernel_size=4,stride=1,padding=0)
        self.bn4 = nn.BatchNorm2d(128)
        
        self.pool = nn.MaxPool2d(kernel_size=3, stride=3)
        self.pool2= nn.MaxPool2d(kernel_size=3, stride=2)
        
        self.fc1 = nn.Linear(6*6*128,512)
        self.fc2 = nn.Linear(512,num_classes)
        
        self.flatten = nn.Flatten()
        self.relu = nn.ReLU() 
        self.dropout = nn.Dropout(0.5)
        
        
        
        
    def forward(self,x):
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)
        x = self.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        x = self.relu(self.bn3(self.conv3(x)))
        x = self.pool2(x)
        x = self.relu(self.bn4(self.conv4(x)))
        x = self.flatten(x)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
model = MyModel(num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr=0.0002)

# %%
def train_epoch():
    model.train()
    total_loss = 0.0 
    total_correct = 0
    total_predictions = 0
    
    for batch_number, (images, labels_indices, labels) in enumerate(train_loader):
        images, labels_indices = images.to(device), labels_indices.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(images)
        loss = criterion(outputs, labels_indices)
        total_loss += loss.item()
        
        # Calculate accuracy
        _, predicted = torch.max(outputs, 1)
        total_predictions += labels_indices.size(0)
        total_correct += (predicted == labels_indices).sum().item()
        
        loss.backward()
        optimizer.step()
        
        if (batch_number and batch_number % 150 == 0):
            c_loss = total_loss / (batch_number + 1)
            accuracy = total_correct / total_predictions
            print(f"Batch {batch_number}/{len(train_loader)}, Loss: {c_loss:0.4f}, Accuracy: {accuracy * 100:.2f}%")
    
    avg_loss = total_loss / len(train_loader)
    avg_accuracy = total_correct / total_predictions
    
    return avg_loss, avg_accuracy

# %%
def eval_model():
    model.eval()
    total_loss = 0.0 
    total_correct = 0
    total_predictions = 0
    
    with torch.no_grad():
        for batch_number, (images, labels_indices, labels) in enumerate(val_loader):
            images, labels_indices = images.to(device), labels_indices.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels_indices)
            total_loss += loss.item()
            
            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total_predictions += labels_indices.size(0)
            total_correct += (predicted == labels_indices).sum().item()
            
    avg_loss = total_loss / len(val_loader)
    avg_accuracy = total_correct / total_predictions
    
    return avg_loss, avg_accuracy

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# %%
best_score = float("inf")
n_epochs = 40
tolerance = 0

for epoch in range(n_epochs):
    print(f"Epoch {epoch},   ", end="")
    avg_train_loss, train_accuracy = train_epoch()
    avg_eval_loss, eval_accuracy = eval_model()
    
    if avg_eval_loss < best_score:
        best_score = avg_eval_loss
        torch.save(model.state_dict(), f"model_{epoch+1}")
        tolerance = 0
    else:
        tolerance += 1
        if tolerance >= 8:
            break
            
    train_losses.append(avg_train_loss)
    val_losses.append(avg_eval_loss)
    train_accuracies.append(train_accuracy)
    val_accuracies.append(eval_accuracy)
    
    print(f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy * 100:.2f}%")
    print(f"Eval Loss: {avg_eval_loss:.4f}, Eval Accuracy: {eval_accuracy * 100:.2f}%")
    print("#" * 70)
# Out:
# Epoch 0,   Batch 150/179, Loss: 0.6135, Accuracy: 76.08%
# Train Loss: 0.5900, Train Accuracy: 77.22%
# Eval Loss: 0.5961, Eval Accuracy: 76.18%
# ######################################################################
# Epoch 1,   Batch 150/179, Loss: 0.3695, Accuracy: 86.36%
# Train Loss: 0.3630, Train Accuracy: 86.57%
# Eval Loss: 0.4271, Eval Accuracy: 83.36%
# ######################################################################
# Epoch 2,   Batch 150/179, Loss: 0.2967, Accuracy: 88.80%
# Train Loss: 0.2926, Train Accuracy: 89.04%
# Eval Loss: 0.4571, Eval Accuracy: 83.82%
# ######################################################################
# Epoch 3,   Batch 150/179, Loss: 0.2498, Accuracy: 91.10%
# Train Loss: 0.2453, Train Accuracy: 91.30%
# Eval Loss: 0.2756, Eval Accuracy: 89.01%
# ######################################################################
# Epoch 4,   Batch 150/179, Loss: 0.2249, Accuracy: 91.74%
# Train Loss: 0.2197, Train Accuracy: 92.03%
# Eval Loss: 0.3264, Eval Accuracy: 85.95%
# ######################################################################
# Epoch 5,   Batch 150/179, Loss: 0.1821, Accuracy: 93.36%
# Train Loss: 0.1819, Train Accuracy: 93.29%
# Eval Loss: 0.5848, Eval Accuracy: 82.29%
# ######################################################################
# Epoch 6,   Batch 150/179, Loss: 0.1749, Accuracy: 93.71%
# Train Loss: 0.1746, Train Accuracy: 93.71%
# Eval Loss: 0.3138, Eval Accuracy: 90.23%
# ######################################################################
# Epoch 7,   Batch 150/179, Loss: 0.1651, Accuracy: 93.96%
# Train Loss: 0.1623, Train Accuracy: 93.93%
# Eval Loss: 0.1717, Eval Accuracy: 93.44%
# ######################################################################
# Epoch 8,   Batch 150/179, Loss: 0.1314, Accuracy: 95.38%
# Train Loss: 0.1342, Train Accuracy: 95.22%
# Eval Loss: 0.2178, Eval Accuracy: 91.91%
# ######################################################################
# Epoch 9,   Batch 150/179, Loss: 0.1265, Accuracy: 95.41%
# Train Loss: 0.1305, Train Accuracy: 95.27%
# Eval Loss: 0.2102, Eval Accuracy: 93.28%
# ######################################################################
# Epoch 10,   Batch 150/179, Loss: 0.1280, Accuracy: 95.65%
# Train Loss: 0.1288, Train Accuracy: 95.48%
# Eval Loss: 0.3129, Eval Accuracy: 89.92%
# ######################################################################
# Epoch 11,   Batch 150/179, Loss: 0.0958, Accuracy: 96.71%
# Train Loss: 0.1010, Train Accuracy: 96.43%
# Eval Loss: 0.2203, Eval Accuracy: 91.76%
# ######################################################################
# Epoch 12,   Batch 150/179, Loss: 0.1001, Accuracy: 96.42%
# Train Loss: 0.0996, Train Accuracy: 96.43%
# Eval Loss: 0.2106, Eval Accuracy: 92.98%
# ######################################################################
# Epoch 13,   Batch 150/179, Loss: 0.0798, Accuracy: 97.06%
# Train Loss: 0.0815, Train Accuracy: 96.97%
# Eval Loss: 0.1611, Eval Accuracy: 94.81%
# ######################################################################
# Epoch 14,   Batch 150/179, Loss: 0.0873, Accuracy: 96.77%
# Train Loss: 0.0886, Train Accuracy: 96.73%
# Eval Loss: 0.1790, Eval Accuracy: 92.98%
# ######################################################################
# Epoch 15,   Batch 150/179, Loss: 0.0966, Accuracy: 96.46%
# Train Loss: 0.0917, Train Accuracy: 96.66%
# Eval Loss: 0.0936, Eval Accuracy: 95.88%
# ######################################################################
# Epoch 16,   Batch 150/179, Loss: 0.0660, Accuracy: 97.50%
# Train Loss: 0.0665, Train Accuracy: 97.50%
# Eval Loss: 0.1623, Eval Accuracy: 95.11%
# ######################################################################
# Epoch 17,   Batch 150/179, Loss: 0.0719, Accuracy: 97.39%
# Train Loss: 0.0696, Train Accuracy: 97.55%
# Eval Loss: 0.1089, Eval Accuracy: 96.49%
# ######################################################################
# Epoch 18,   Batch 150/179, Loss: 0.0588, Accuracy: 98.01%
# Train Loss: 0.0627, Train Accuracy: 97.86%
# Eval Loss: 0.2261, Eval Accuracy: 92.52%
# ######################################################################
# Epoch 19,   Batch 150/179, Loss: 0.0671, Accuracy: 97.68%
# Train Loss: 0.0664, Train Accuracy: 97.71%
# Eval Loss: 0.2155, Eval Accuracy: 93.59%
# ######################################################################
# Epoch 20,   Batch 150/179, Loss: 0.0627, Accuracy: 97.54%
# Train Loss: 0.0614, Train Accuracy: 97.62%
# Eval Loss: 0.1057, Eval Accuracy: 97.56%
# ######################################################################
# Epoch 21,   Batch 150/179, Loss: 0.0583, Accuracy: 97.97%
# Train Loss: 0.0596, Train Accuracy: 97.92%
# Eval Loss: 0.0438, Eval Accuracy: 98.63%
# ######################################################################
# Epoch 22,   Batch 150/179, Loss: 0.0421, Accuracy: 98.57%
# Train Loss: 0.0465, Train Accuracy: 98.55%
# Eval Loss: 0.0971, Eval Accuracy: 96.79%
# ######################################################################
# Epoch 23,   Batch 150/179, Loss: 0.0459, Accuracy: 98.32%
# Train Loss: 0.0459, Train Accuracy: 98.32%
# Eval Loss: 0.1057, Eval Accuracy: 95.57%
# ######################################################################
# Epoch 24,   Batch 150/179, Loss: 0.0420, Accuracy: 98.43%
# Train Loss: 0.0451, Train Accuracy: 98.32%
# Eval Loss: 0.1541, Eval Accuracy: 94.96%
# ######################################################################
# Epoch 25,   Batch 150/179, Loss: 0.0434, Accuracy: 98.47%
# Train Loss: 0.0443, Train Accuracy: 98.48%
# Eval Loss: 0.1636, Eval Accuracy: 93.74%
# ######################################################################
# Epoch 26,   Batch 150/179, Loss: 0.0458, Accuracy: 98.30%
# Train Loss: 0.0460, Train Accuracy: 98.25%
# Eval Loss: 0.2351, Eval Accuracy: 93.44%
# ######################################################################
# Epoch 27,   Batch 150/179, Loss: 0.0556, Accuracy: 98.08%
# Train Loss: 0.0547, Train Accuracy: 98.02%
# Eval Loss: 0.1950, Eval Accuracy: 93.74%
# ######################################################################
# Epoch 28,   Batch 150/179, Loss: 0.0440, Accuracy: 98.41%
# Train Loss: 0.0446, Train Accuracy: 98.37%
# Eval Loss: 0.0433, Eval Accuracy: 98.47%
# ######################################################################
# Epoch 29,   Batch 150/179, Loss: 0.0349, Accuracy: 98.76%
# Train Loss: 0.0341, Train Accuracy: 98.79%
# Eval Loss: 0.0566, Eval Accuracy: 97.86%
# ######################################################################
# Epoch 30,   Batch 150/179, Loss: 0.0409, Accuracy: 98.53%
# Train Loss: 0.0401, Train Accuracy: 98.53%
# Eval Loss: 0.0609, Eval Accuracy: 98.02%
# ######################################################################
# Epoch 31,   Batch 150/179, Loss: 0.0409, Accuracy: 98.53%
# Train Loss: 0.0426, Train Accuracy: 98.42%
# Eval Loss: 0.1892, Eval Accuracy: 93.59%
# ######################################################################
# Epoch 32,   Batch 150/179, Loss: 0.0435, Accuracy: 98.53%
# Train Loss: 0.0437, Train Accuracy: 98.46%
# Eval Loss: 0.0604, Eval Accuracy: 98.32%
# ######################################################################
# Epoch 33,   Batch 150/179, Loss: 0.0346, Accuracy: 98.70%
# Train Loss: 0.0356, Train Accuracy: 98.69%
# Eval Loss: 0.0366, Eval Accuracy: 98.93%
# ######################################################################
# Epoch 34,   Batch 150/179, Loss: 0.0246, Accuracy: 99.09%
# Train Loss: 0.0263, Train Accuracy: 99.04%
# Eval Loss: 0.1201, Eval Accuracy: 95.88%
# ######################################################################
# Epoch 35,   Batch 150/179, Loss: 0.0325, Accuracy: 99.01%
# Train Loss: 0.0366, Train Accuracy: 98.84%
# Eval Loss: 0.0687, Eval Accuracy: 97.56%
# ######################################################################
# Epoch 36,   Batch 150/179, Loss: 0.0425, Accuracy: 98.34%
# Train Loss: 0.0419, Train Accuracy: 98.41%
# Eval Loss: 0.0926, Eval Accuracy: 97.10%
# ######################################################################
# Epoch 37,   Batch 150/179, Loss: 0.0357, Accuracy: 98.80%
# Train Loss: 0.0330, Train Accuracy: 98.90%
# Eval Loss: 0.0563, Eval Accuracy: 98.47%
# ######################################################################
# Epoch 38,   Batch 150/179, Loss: 0.0323, Accuracy: 98.94%
# Train Loss: 0.0330, Train Accuracy: 98.91%
# Eval Loss: 0.0742, Eval Accuracy: 97.71%
# ######################################################################
# Epoch 39,   Batch 150/179, Loss: 0.0285, Accuracy: 99.11%
# Train Loss: 0.0291, Train Accuracy: 99.05%
# Eval Loss: 0.0583, Eval Accuracy: 98.63%
# ######################################################################

# %%
# Visualize training history
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss History')

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy History')

plt.tight_layout()
plt.show()

# %%
models = glob("/kaggle/working/*")
model_num = [int(i.split("_")[-1]) for i in models if i.split("_")[-1].isdigit()]
best_model_path = "/kaggle/working/model_" + str(sorted(model_num)[-1])
best_model_path
# Out:
# '/kaggle/working/model_34'

# %%
best_model = MyModel(num_classes).to(device)

best_model.load_state_dict(torch.load(best_model_path, map_location=device))
# Out:
# <All keys matched successfully>

# %%
def predict(
    model:nn.Module, 
    sample_loader:torch.utils.data.DataLoader,
    device:torch.device) -> np.ndarray:
    model.eval()
    predictions = []
    with torch.inference_mode():
        for batch, (X, y,labels) in enumerate(sample_loader):
            X, y = X.to(device), y.to(device)
            y_pred = model(X) 
            predictions.append(y_pred.cpu().numpy())
        
    return np.vstack(predictions)

# %%
best_model_props = predict(best_model, test_loader, device)
best_model_preds = np.argmax(best_model_props, axis=1)
best_model_preds.shape[0]
# Out:
# 656

# %%
gen_labels_test_set = [label[1] for label in test_dataset]
len(gen_labels_test_set)
# Out:
# 656

# %%
print(f"Best Model Test Accuracy: {round(accuracy_score(gen_labels_test_set,best_model_preds)*100,2)}%")
# Out:
# Best Model Test Accuracy: 99.24%

# %%
cm = confusion_matrix(gen_labels_test_set, best_model_preds)
labels = set([label[2] for label in test_dataset])
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label', labelpad=20, fontsize=14)
plt.ylabel('Truth Label', labelpad=20, fontsize=14)
plt.show()
